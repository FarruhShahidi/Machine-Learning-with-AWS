# %%
# !pip3 install tqdm
# !pip3 install pillow --upgrade
# Out:
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (4.42.1)
# WARNING: You are using pip version 20.3; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/tensorflow_p36/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: pillow in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (7.0.0)
# Collecting pillow
#   Downloading Pillow-8.1.0-cp36-cp36m-manylinux1_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 6.1 MB/s eta 0:00:01
# Installing collected packages: pillow
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 7.0.0
#     Uninstalling Pillow-7.0.0:
#       Successfully uninstalled Pillow-7.0.0
# Successfully installed pillow-8.1.0
# WARNING: You are using pip version 20.3; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/tensorflow_p36/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# __IMPORT LIBRARIES__

# %%
import os
import tarfile
import urllib
import shutil
import json
import random
import numpy as np
import boto3
import sagemaker

from tqdm import tqdm
from sagemaker.amazon.amazon_estimator import get_image_uri
from matplotlib import pyplot as plt
from xml.etree import ElementTree as ET
from PIL import Image, ImageDraw, ImageFont

# %matplotlib inline

urls = ['http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz',
        'http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz']

def download_and_extract(data_dir, download_dir):
    for url in urls:
        target_file = url.split('/')[-1]
        if target_file not in os.listdir(download_dir):
            print('Downloading', url)
            urllib.request.urlretrieve(url, os.path.join(download_dir, target_file))
            tf = tarfile.open(url.split('/')[-1])
            tf.extractall(data_dir)
        else:
            print('Already downloaded', url)

if not os.path.isdir('data'):
    os.mkdir('data')

download_and_extract('data', '.')
# Out:
# Downloading http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# Downloading http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz

# %% [markdown]
# __DATA VISUALIZATION__

# %%
trimaps_dir = 'data/annotations/trimaps/'

maps = [x for x in os.listdir(trimaps_dir) if x[-3:] == 'png']
print(len(maps))
# Out:
# 14780

# %%
image_dir = 'data/images/'

images = [x for x in os.listdir(image_dir) if x[-3:] == 'jpg']
print(len(images))
# Out:
# 7390

# %%
images[1]
# Out:
# 'Russian_Blue_78.jpg'

# %%
plt.figure(figsize=(12, 12))

for i in range(0, 4):
    index = random.randint(0, len(images) - 1)
    image_name = images[index]
    map_name = images[index].split('.')[0] + '.png'

    plt.subplot(4, 2, 1 + i*2)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(plt.imread(os.path.join(trimaps_dir, map_name)))
    plt.subplot(4, 2, 2 + i*2)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(plt.imread(os.path.join(image_dir, image_name)))
plt.show()

# %%
img = Image.open(os.path.join(trimaps_dir, maps[0]))
print(np.unique(img))
# Out:
# [1 2 3]

# %% [markdown]
# __SAGEMAKER__

# %%
role = sagemaker.get_execution_role()
bucket_name = 'semantic-imagespets'
training_image = get_image_uri(boto3.Session().region_name, 'semantic-segmentation',
                              repo_version='latest')
print(training_image)
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: latest.
# 825641698319.dkr.ecr.us-east-2.amazonaws.com/semantic-segmentation:1

# %%
folders = ['train', 'train_annotation', 'validation', 'validation_annotation']

for folder in folders:
    if os.path.isdir(folder):
        shutil.rmtree(folder)
    os.mkdir(folder)

# %% [markdown]
# __DATA PREPARATION__

# %%
def get_map_file(image):
    map_file = image.split('.')[0] + '.png'
    assert map_file in maps
    return map_file
    
for image in tqdm(images):
    target_set = 'train' if random.randint(0, 99) < 75 else 'validation'
    
    image_file_path = os.path.join('data/images/', image)
    image_target_path = os.path.join(target_set, image)
    
    map_file_path = os.path.join(trimaps_dir, get_map_file(image))
    map_target_path = os.path.join(target_set + '_annotation', get_map_file(image))
    
    shutil.copy(image_file_path, image_target_path)
    shutil.copy(map_file_path, map_target_path)
# Out:
# 100%|██████████| 7390/7390 [00:03<00:00, 1862.44it/s]

# %%
train_images = os.listdir('train')
train_annots = os.listdir('train_annotation')

# %%
print(len(train_annots), len(train_images))
# Out:
# 5554 5554

# %% [markdown]
# __UPLOADING DATA TO S3__

# %%
# %%time
sess = sagemaker.Session()

print('Starting upload..')
s3_train_path = sess.upload_data(path='train', bucket=bucket_name, key_prefix='train')
print('Training images uploaded')
s3_train_annotation_path = sess.upload_data(path='train_annotation', bucket=bucket_name,
                                     key_prefix='train_annotation')
print('Training Annotations uploaded')
s3_validation_path = sess.upload_data(path='validation', bucket=bucket_name,
                                      key_prefix='validation')
print('Validation images uploaded')
s3_validation_annotation_path = sess.upload_data(path='validation_annotation', bucket=bucket_name,
                                          key_prefix='validation_annotation')
print('Validation Annotations uploaded')
# Out:
# Starting upload..
# Training images uploaded
# Training Annotations uploaded
# Validation images uploaded
# Validation Annotations uploaded
# CPU times: user 1min 43s, sys: 6.94 s, total: 1min 50s
# Wall time: 11min 21s

# %%
s3_validation_annotation_path
# Out:
# 's3://semantic-imagespets/validation_annotation'

# %% [markdown]
# __SAGEMAKER ESTIMATOR__

# %%
model = sagemaker.estimator.Estimator(
    training_image,
    role=role,
    instance_count=1,
    instance_type='ml.p2.xlarge',
    volume_size=100,
    max_run=36000,
    input_mode='File',
    output_path='s3://semantic-imagespets/output',
    sagemaker_session=sess
)

# %% [markdown]
# __HYPERPARAMETER TUNING__

# %%
model.set_hyperparameters(
    backbone='resnet-50', # This is the encoder. Other option is resnet-50
    algorithm='fcn', # This is the decoder. Other option is 'psp' and 'deeplab'                             
    use_pretrained_model='True', # Use the pre-trained model.
    crop_size=240, # Size of image random crop.                             
    num_classes=4, # Pascal has 21 classes. This is a mandatory parameter.
    epochs=10, # Number of epochs to run.
    learning_rate=0.0001,                             
    optimizer='rmsprop', # Other options include 'adam', 'rmsprop', 'nag', 'adagrad'.
    lr_scheduler='poly', # Other options include 'cosine' and 'step'.                           
    mini_batch_size=16, # Setup some mini batch size.
    validation_mini_batch_size=16,
    early_stopping=True, # Turn on early stopping. If OFF, other early stopping parameters are ignored.
    early_stopping_patience=3, # Tolerate these many epochs if the mIoU doens't increase.
    early_stopping_min_epochs=10, # No matter what, run these many number of epochs.                             
    num_training_samples=len(train_images)
)

# %% [markdown]
# __DATA CHANNELS__

# %%
train_data = sagemaker.inputs.TrainingInput(s3_train_path, distribution='FullyReplicated',
                          content_type='image/jpeg', s3_data_type='S3Prefix')
validation_data = sagemaker.inputs.TrainingInput(s3_validation_path, distribution='FullyReplicated',
                          content_type='image/jpeg', s3_data_type='S3Prefix')

train_annotation_data = sagemaker.inputs.TrainingInput(s3_train_annotation_path, distribution='FullyReplicated',
                          content_type='image/png', s3_data_type='S3Prefix')
validation_annotation_data = sagemaker.inputs.TrainingInput(s3_validation_annotation_path, distribution='FullyReplicated',
                          content_type='image/png', s3_data_type='S3Prefix')

# %%
data_channels = {
    'train': train_data,
    'train_annotation': train_annotation_data,
    'validation': validation_data,
    'validation_annotation': validation_annotation_data
}

# %%
model.fit(inputs=data_channels, logs=True)
# Out:
# 2021-01-18 17:05:31 Starting - Starting the training job...
# 2021-01-18 17:05:54 Starting - Launching requested ML instancesProfilerReport-1610989530: InProgress
# ......
# 2021-01-18 17:06:57 Starting - Preparing the instances for training..................
# 2021-01-18 17:09:57 Downloading - Downloading input data............
# 2021-01-18 17:11:59 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# Running custom environment configuration script
# [01/18/2021 17:12:00 INFO 140680639121216] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'syncbn': u'False', u'gamma2': u'0.9', u'gamma1': u'0.9', u'early_stopping_min_epochs': u'5', u'epochs': u'10', u'_workers': u'16', u'lr_scheduler_factor': u'0.1', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0001', u'crop_size': u'240', u'use_pretrained_model': u'True', u'_aux_weight': u'0.5', u'_hybrid': u'False', u'_augmentation_type': u'default', u'lr_scheduler': u'poly', u'early_stopping_patience': u'4', u'momentum': u'0.9', u'optimizer': u'sgd', u'early_stopping_tolerance': u'0.0', u'learning_rate': u'0.001', u'backbone': u'resnet-50', u'validation_mini_batch_size': u'16', u'_aux_loss': u'True', u'mini_batch_size': u'16', u'early_stopping': u'False', u'algorithm': u'fcn', u'_logging_frequency': u'20', u'num_training_samples': u'8', u'_kvstore': u'device', u'precision_dtype': u'float32'}
# [01/18/2021 17:12:00 INFO 140680639121216] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'learning_rate': u'0.0001', u'optimizer': u'rmsprop', u'algorithm': u'fcn', u'lr_scheduler': u'poly', u'use_pretrained_model': u'True', u'backbone': u'resnet-50', u'early_stopping_min_epochs': u'10', u'epochs': u'10', u'validation_mini_batch_size': u'16', u'num_training_samples': u'5554', u'num_classes': u'4', u'mini_batch_size': u'16', u'early_stopping_patience': u'3', u'early_stopping': u'True', u'crop_size': u'240'}
# [01/18/2021 17:12:00 INFO 140680639121216] Final configuration: {u'syncbn': u'False', u'gamma2': u'0.9', u'gamma1': u'0.9', u'early_stopping_min_epochs': u'10', u'epochs': u'10', u'_workers': u'16', u'lr_scheduler_factor': u'0.1', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0001', u'crop_size': u'240', u'use_pretrained_model': u'True', u'_aux_weight': u'0.5', u'_hybrid': u'False', u'_augmentation_type': u'default', u'lr_scheduler': u'poly', u'num_classes': u'4', u'early_stopping_patience': u'3', u'momentum': u'0.9', u'optimizer': u'rmsprop', u'early_stopping_tolerance': u'0.0', u'learning_rate': u'0.0001', u'backbone': u'resnet-50', u'validation_mini_batch_size': u'16', u'_aux_loss': u'True', u'mini_batch_size': u'16', u'early_stopping': u'True', u'algorithm': u'fcn', u'_logging_frequency': u'20', u'num_training_samples': u'5554', u'_kvstore': u'device', u'precision_dtype': u'float32'}
# Process 1 is a worker.
# [01/18/2021 17:12:00 INFO 140680639121216] Using default worker.
# [01/18/2021 17:12:01 INFO 140680639121216] font search path ['/opt/amazon/lib/python2.7/site-packages/matplotlib/mpl-data/fonts/ttf', '/opt/amazon/lib/python2.7/site-packages/matplotlib/mpl-data/fonts/afm', '/opt/amazon/lib/python2.7/site-packages/matplotlib/mpl-data/fonts/pdfcorefonts']
# [01/18/2021 17:12:01 INFO 140680639121216] generated new fontManager
# [01/18/2021 17:12:02 INFO 140680639121216] Loaded iterator creator application/x-image for content type ('application/x-image', '1.0')
# [01/18/2021 17:12:02 INFO 140680639121216] Loaded iterator creator application/x-recordio for content type ('application/x-recordio', '1.0')
# [01/18/2021 17:12:02 INFO 140680639121216] Loaded iterator creator image/png for content type ('image/png', '1.0')
# [01/18/2021 17:12:02 INFO 140680639121216] Loaded iterator creator application/json for content type ('application/json', '1.0')
# [01/18/2021 17:12:02 INFO 140680639121216] Loaded iterator creator image/jpeg for content type ('image/jpeg', '1.0')
# [01/18/2021 17:12:02 INFO 140680639121216] Checkpoint loading and saving are disabled.
# [01/18/2021 17:12:04 WARNING 140680639121216] /opt/ml/input/data/train/train_annotation is not a readable image file
# [01/18/2021 17:12:07 WARNING 140680639121216] label maps not provided, using defaults.
# [01/18/2021 17:12:07 INFO 140680639121216] #label_map train :{'scale': 1}
# [01/18/2021 17:12:07 WARNING 140680639121216] /opt/ml/input/data/validation/validation_annotation is not a readable image file
# [01/18/2021 17:12:10 WARNING 140680639121216] label maps not provided, using defaults.
# [01/18/2021 17:12:10 INFO 140680639121216] #label_map validation :{'scale': 1}
# [01/18/2021 17:12:10 INFO 140680639121216] nvidia-smi took: 0.0252919197083 secs to identify 1 gpus
# [01/18/2021 17:12:10 INFO 140680639121216] Number of GPUs being used: 1
# [01/18/2021 17:12:10 INFO 140680639121216] Number of GPUs being used: 1
# [01/18/2021 17:12:10 INFO 140680639121216] Number of GPUs being used: 1
# [17:12:13] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x.1856.0/AL2012/generic-flavor/src/src/storage/storage.cc:108: Using GPUPooledRoundedStorageManager.
# [01/18/2021 17:12:18 INFO 140680639121216] LRScheduler setup: iters per epoch: 347, num_epochs 10
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1610989938.252946, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/Semantic Segmentation"}, "StartTime": 1610989938.25275}
#
# [01/18/2021 17:12:59 INFO 140680639121216] #progress_notice. epoch: 0, iterations: 20 speed: 8.78847481564 samples/sec learning_rate: 0.000099
# [01/18/2021 17:13:36 INFO 140680639121216] #progress_notice. epoch: 0, iterations: 40 speed: 8.71051713779 samples/sec learning_rate: 0.000099
# [01/18/2021 17:14:13 INFO 140680639121216] #progress_notice. epoch: 0, iterations: 60 speed: 8.6181215028 samples/sec learning_rate: 0.000098
# [01/18/2021 17:14:50 INFO 140680639121216] #progress_notice. epoch: 0, iterations: 80 speed: 8.57342532984 samples/sec learning_rate: 0.000098
# [01/18/2021 17:15:28 INFO 140680639121216] #progress_notice. epoch: 0, iterations: 100 speed: 8.56689690406 samples/sec learning_rate: 0.000097
# [01/18/2021 17:16:06 INFO 140680639121216] #progress_notice. epoch: 0, iterations: 120 speed: 8.50513256876 samples/sec learning_rate: 0.000097
# [01/18/2021 17:16:43 INFO 140680639121216] #progress_notice. epoch: 0, iterations: 140 speed: 8.55057622125 samples/sec learning_rate: 0.000096
# [01/18/2021 17:17:21 INFO 140680639121216] #progress_notice. epoch: 0, iterations: 160 speed: 8.48858120406 samples/sec learning_rate: 0.000096
# [01/18/2021 17:17:58 INFO 140680639121216] #progress_notice. epoch: 0, iterations: 180 speed: 8.55200147111 samples/sec learning_rate: 0.000095
# [01/18/2021 17:18:36 INFO 140680639121216] #progress_notice. epoch: 0, iterations: 200 speed: 8.52041022578 samples/sec learning_rate: 0.000095
# [01/18/2021 17:19:13 INFO 140680639121216] #progress_notice. epoch: 0, iterations: 220 speed: 8.57913010418 samples/sec learning_rate: 0.000094
# [01/18/2021 17:19:51 INFO 140680639121216] #progress_notice. epoch: 0, iterations:
"Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Semantic Segmentation", "epoch": 7}, "StartTime": 1610995082.080173}
#
# [01/18/2021 18:51:05 INFO 140680639121216] #progress_notice. epoch: 8, iterations: 20 speed: 8.88961562458 samples/sec learning_rate: 0.000023
# [01/18/2021 18:51:41 INFO 140680639121216] #progress_notice. epoch: 8, iterations: 40 speed: 8.8054526238 samples/sec learning_rate: 0.000022
# [01/18/2021 18:52:17 INFO 140680639121216] #progress_notice. epoch: 8, iterations: 60 speed: 8.92710194841 samples/sec learning_rate: 0.000022
# [01/18/2021 18:52:53 INFO 140680639121216] #progress_notice. epoch: 8, iterations: 80 speed: 8.94758010593 samples/sec learning_rate: 0.000021
# [01/18/2021 18:53:30 INFO 140680639121216] #progress_notice. epoch: 8, iterations: 100 speed: 8.89534229289 samples/sec learning_rate: 0.000020
# [01/18/2021 18:54:06 INFO 140680639121216] #progress_notice. epoch: 8, iterations: 120 speed: 8.85826431576 samples/sec learning_rate: 0.000020
# [01/18/2021 18:54:42 INFO 140680639121216] #progress_notice. epoch: 8, iterations: 140 speed: 8.90455104434 samples/sec learning_rate: 0.000019
# [01/18/2021 18:55:18 INFO 140680639121216] #progress_notice. epoch: 8, iterations: 160 speed: 8.9134012088 samples/sec learning_rate: 0.000018
# [01/18/2021 18:55:54 INFO 140680639121216] #progress_notice. epoch: 8, iterations: 180 speed: 8.8979948478 samples/sec learning_rate: 0.000018
# [01/18/2021 18:56:30 INFO 140680639121216] #progress_notice. epoch: 8, iterations: 200 speed: 8.87365178968 samples/sec learning_rate: 0.000017
# [01/18/2021 18:57:06 INFO 140680639121216] #progress_notice. epoch: 8, iterations: 220 speed: 8.90527892533 samples/sec learning_rate: 0.000017
# [01/18/2021 18:57:42 INFO 140680639121216] #progress_notice. epoch: 8, iterations: 240 speed: 8.92419465792 samples/sec learning_rate: 0.000016
# [01/18/2021 18:58:18 INFO 140680639121216] #progress_notice. epoch: 8, iterations: 260 speed: 8.90354095214 samples/sec learning_rate: 0.000015
# [01/18/2021 18:58:54 INFO 140680639121216] #progress_notice. epoch: 8, iterations: 280 speed: 8.88071388862 samples/sec learning_rate: 0.000015
# [01/18/2021 18:59:31 INFO 140680639121216] #progress_notice. epoch: 8, iterations: 300 speed: 8.86568608308 samples/sec learning_rate: 0.000014
# [01/18/2021 19:00:07 INFO 140680639121216] #progress_notice. epoch: 8, iterations: 320 speed: 8.86300827294 samples/sec learning_rate: 0.000013
# [01/18/2021 19:00:43 INFO 140680639121216] #progress_notice. epoch: 8, iterations: 340 speed: 8.85100555113 samples/sec learning_rate: 0.000013
# [01/18/2021 19:00:55 INFO 140680639121216] #quality_metric. host: algo-1, epoch: 8, train loss: 0.32346614018640873 .
# [01/18/2021 19:00:55 INFO 140680639121216] #throughput_metric. host: algo-1, epoch: 8, train throughput: 8.87407760502 samples/sec.
# [01/18/2021 19:01:12 INFO 140680639121216] #progress_notice. epoch: 8, iterations: 20 speed: 23.9946253418 samples/sec
# [01/18/2021 19:01:26 INFO 140680639121216] #progress_notice. epoch: 8, iterations: 40 speed: 23.6280263909 samples/sec
# [01/18/2021 19:01:39 INFO 140680639121216] #progress_notice. epoch: 8, iterations: 60 speed: 23.7836547424 samples/sec
# [01/18/2021 19:01:53 INFO 140680639121216] #progress_notice. epoch: 8, iterations: 80 speed: 23.6666149432 samples/sec
# [01/18/2021 19:02:07 INFO 140680639121216] #progress_notice. epoch: 8, iterations: 100 speed: 22.6819364773 samples/sec
# [01/18/2021 19:02:16 INFO 140680639121216] #quality_metric. host: algo-1, epoch: 8, validation pixel_accuracy: 0.925506470440424 .
# [01/18/2021 19:02:16 INFO 140680639121216] #quality_metric. host: algo-1, epoch: 8, validation mIOU: 0.6050038576347269 .
# [01/18/2021 19:02:16 INFO 140680639121216] #throughput_metric. host: algo-1, epoch: 8, validation throughput: 23.180004526 samples/sec.
# [01/18/2021 19:02:16 INFO 140680639121216] Serializing model to /opt/ml/model/model_best.params
# [01/18/2021 19:02:17 INFO 140680639121216] #progress_metric: host=algo-1, completed 90 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 9, "sum": 9.0, "min": 9}}, "EndTime": 1610996537.042296, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Semantic Segmentation", "epoch": 8}, "StartTime": 1610995825.977245}
#
# [01/18/2021 19:02:56 INFO 140680639121216] #progress_notice. epoch: 9, iterations: 20 speed: 8.88881495031 samples/sec learning_rate: 0.000012
# [01/18/2021 19:03:32 INFO 140680639121216] #progress_notice. epoch: 9, iterations: 40 speed: 8.88426914959 samples/sec learning_rate: 0.000011
# [01/18/2021 19:04:09 INFO 140680639121216] #progress_notice. epoch: 9, iterations: 60 speed: 8.927485534 samples/sec learning_rate: 0.000011
# [01/18/2021 19:04:45 INFO 140680639121216] #progress_notice. epoch: 9, iterations: 80 speed: 8.91507907999 samples/sec learning_rate: 0.000010
# [01/18/2021 19:05:21 INFO 140680639121216] #progress_notice. epoch: 9, iterations: 100 speed: 8.88548192805 samples/sec learning_rate: 0.000009
# [01/18/2021 19:05:57 INFO 140680639121216] #progress_notice. epoch: 9, iterations: 120 speed: 8.90425449058 samples/sec learning_rate: 0.000009
# [01/18/2021 19:06:33 INFO 140680639121216] #progress_notice. epoch: 9, iterations: 140 speed: 8.7892770838 samples/sec learning_rate: 0.000008
# [01/18/2021 19:07:09 INFO 140680639121216] #progress_notice. epoch: 9, iterations: 160 speed: 8.89218464309 samples/sec learning_rate: 0.000007
# [01/18/2021 19:07:45 INFO 140680639121216] #progress_notice. epoch: 9, iterations: 180 speed: 8.90254053703 samples/sec learning_rate: 0.000006
# [01/18/2021 19:08:22 INFO 140680639121216] #progress_notice. epoch: 9, iterations: 200 speed: 8.89510530294 samples/sec learning_rate: 0.000006
# [01/18/2021 19:08:58 INFO 140680639121216] #progress_notice. epoch: 9, iterations: 220 speed: 8.88386457166 samples/sec learning_rate: 0.000005
# [01/18/2021 19:09:34 INFO 140680639121216] #progress_notice. epoch: 9, iterations: 240 speed: 8.89439440886 samples/sec learning_rate: 0.000004
# [01/18/2021 19:10:10 INFO 140680639121216] #progress_notice. epoch: 9, iterations: 260 speed: 8.76399625144 samples/sec learning_rate: 0.000004
# [01/18/2021 19:10:47 INFO 140680639121216] #progress_notice. epoch: 9, iterations: 280 speed: 8.83773739557 samples/sec learning_rate: 0.000003
# [01/18/2021 19:11:23 INFO 140680639121216] #progress_notice. epoch: 9, iterations: 300 speed: 8.82532710548 samples/sec learning_rate: 0.000002
# [01/18/2021 19:11:59 INFO 140680639121216] #progress_notice. epoch: 9, iterations: 320 speed: 8.82676764242 samples/sec learning_rate: 0.000001
# [01/18/2021 19:12:36 INFO 140680639121216] #progress_notice. epoch: 9, iterations: 340 speed: 8.77915415977 samples/sec learning_rate: 0.000000
# [01/18/2021 19:12:49 INFO 140680639121216] #quality_metric. host: algo-1, epoch: 9, train loss: 0.314148805326962 .
# [01/18/2021 19:12:49 INFO 140680639121216] #throughput_metric. host: algo-1, epoch: 9, train throughput: 8.85320970821 samples/sec.
# [01/18/2021 19:13:05 INFO 140680639121216] #progress_notice. epoch: 9, iterations: 20 speed: 23.6188540139 samples/sec
# [01/18/2021 19:13:19 INFO 140680639121216] #progress_notice. epoch: 9, iterations: 40 speed: 23.4463152047 samples/sec
# [01/18/2021 19:13:33 INFO 140680639121216] #progress_notice. epoch: 9, iterations: 60 speed: 23.4883067483 samples/sec
# [01/18/2021 19:13:47 INFO 140680639121216] #progress_notice. epoch: 9, iterations: 80 speed: 23.6344421388 samples/sec
# [01/18/2021 19:14:01 INFO 140680639121216] #progress_notice. epoch: 9, iterations: 100 speed: 23.1666466445 samples/sec
# [01/18/2021 19:14:11 INFO 140680639121216] #quality_metric. host: algo-1, epoch: 9, validation pixel_accuracy: 0.9258996169233091 .
# [01/18/2021 19:14:11 INFO 140680639121216] #quality_metric. host: algo-1, epoch: 9, validation mIOU: 0.6058544141439339 .
# [01/18/2021 19:14:11 INFO 140680639121216] #throughput_metric. host: algo-1, epoch: 9, validation throughput: 22.9269368911 samples/sec.
# [01/18/2021 19:14:11 INFO 140680639121216] Serializing model to /opt/ml/model/model_best.params
# [01/18/2021 19:14:11 INFO 140680639121216] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1610997251.809701, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Semantic Segmentation", "epoch": 9}, "StartTime": 1610996537.042657}
#
# [01/18/2021 19:14:11 WARNING 140680639121216] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [01/18/2021 19:14:11 INFO 140680639121216] Serializing model to /opt/ml/model/model_algo-1
# [01/18/2021 19:14:12 INFO 140680639121216] Test data is not provided.
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 10, "sum": 10.0, "min": 10}, "totaltime": {"count": 1, "max": 7331492.718935013, "sum": 7331492.718935013, "min": 7331492.718935013}, "setuptime": {"count": 1, "max": 30.49492835998535, "sum": 30.49492835998535, "min": 30.49492835998535}}, "EndTime": 1610997252.36244, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/Semantic Segmentation"}, "StartTime": 1610989922.633023}
#
#
# 2021-01-18 19:14:44 Uploading - Uploading generated training model
# 2021-01-18 19:15:05 Completed - Training job completed
# Training seconds: 7524
# Billable seconds: 7524

# %% [markdown]
# __MODEL DEPLOYMENT__

# %%
deployed_model = model.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
print('\nModel deployed!')
# Out:
# -----------------!
# Model deployed!

# %%
image_dir = 'validation'
images = [x for x in os.listdir(image_dir) if x[-3:] == 'jpg']
print(len(images))
# Out:
# 1836

# %%
#deployed_model.content_type = 'image/jpeg'
#deployed_model.accept = 'image/png'

# %%
index = 2

image_path = os.path.join(image_dir, images[index])
# image_path = 'dog_cat.jfif'

with open(image_path, 'rb') as f:
    b = bytearray(f.read())

results = deployed_model.predict(b, initial_args={"ContentType": "image/jpeg", "Accept": "image/png"})

# %%
import io

mask = np.array(Image.open(io.BytesIO(results)))

# %%
plt.imshow(plt.imread(image_path));

# %%
plt.imshow(mask);
