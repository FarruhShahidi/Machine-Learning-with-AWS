# %%
# !pip3 install tqdm
# !pip3 install pillow --upgrade
# Out:
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (4.42.1)
# WARNING: You are using pip version 20.3; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/tensorflow_p36/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: pillow in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (7.0.0)
# Collecting pillow
#   Downloading Pillow-8.1.0-cp36-cp36m-manylinux1_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 6.4 MB/s eta 0:00:01
# Installing collected packages: pillow
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 7.0.0
#     Uninstalling Pillow-7.0.0:
#       Successfully uninstalled Pillow-7.0.0
# Successfully installed pillow-8.1.0
# WARNING: You are using pip version 20.3; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/tensorflow_p36/bin/python -m pip install --upgrade pip' command.

# %%
# %matplotlib inline

import os
import tarfile
import urllib
import shutil
import json
import random
import numpy as np
import boto3
import sagemaker

from tqdm import tqdm
from sagemaker.amazon.amazon_estimator import get_image_uri
from matplotlib import pyplot as plt
from xml.etree import ElementTree as ET
from PIL import Image, ImageDraw, ImageFont



urls = ['http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz',
        'http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz']

def download_and_extract(data_dir, download_dir):
    for url in urls:
        target_file = url.split('/')[-1]
        if target_file not in os.listdir(download_dir):
            print('Downloading', url)
            urllib.request.urlretrieve(url, os.path.join(download_dir, target_file))
            tf = tarfile.open(url.split('/')[-1])
            tf.extractall(data_dir)
        else:
            print('Already downloaded', url)

if not os.path.isdir('data'):
    os.mkdir('data')

download_and_extract('data', '.')
# Out:
# Downloading http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# Downloading http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz

# %% [markdown]
# __EXTRACK ANNOTATIONS FROM XML FORMAT__

# %%
xml_dir = 'data/annotations/xmls/'
xml_files = [os.path.join(xml_dir, x) for x in os.listdir(xml_dir) if x[-3:] == 'xml']
xml_files[0]
# Out:
# 'data/annotations/xmls/english_setter_119.xml'

# %%
classes = ['cat', 'dog']
categories = [
    {
        'class_id': 0,
        'name': 'cat'
    },
    {
        'class_id': 1,
        'name': 'dog'
    }
]

# %%
def extract_annotation(xml_file_path):
    
    tree = ET.parse(xml_file_path)
    root = tree.getroot()
    annotation = {}
    
    annotation['file'] = root.find('filename').text
    annotation['categories'] = categories
    
    size = root.find('size')
    
    annotation['image_size'] = [{
        'width': int(size.find('width').text),
        'height': int(size.find('height').text),
        'depth': int(size.find('depth').text)
    }]
    
    annotation['annotations'] = []
    
    for item in root.iter('object'):
        class_id = classes.index(item.find('name').text)
        ymin, xmin, ymax, xmax = None, None, None, None
        
        for box in item.findall('bndbox'):
            xmin = int(box.find("xmin").text)
            ymin = int(box.find("ymin").text)
            xmax = int(box.find("xmax").text)
            ymax = int(box.find("ymax").text)
        
            if all([xmin, ymin, xmax, ymax]) is not None:
                 annotation['annotations'].append({
                     'class_id': class_id,
                     'left': xmin,
                     'top': ymin,
                     'width': xmax - xmin,
                     'height': ymax - ymin
                 })
    return annotation

# %%
extract_annotation(xml_files[0])
# Out:
# {'file': 'english_setter_119.jpg',
#  'categories': [{'class_id': 0, 'name': 'cat'},
#   {'class_id': 1, 'name': 'dog'}],
#  'image_size': [{'width': 500, 'height': 349, 'depth': 3}],
#  'annotations': [{'class_id': 1,
#    'left': 298,
#    'top': 66,
#    'width': 144,
#    'height': 117}]}

# %% [markdown]
# __DATA VISUALIZATION__

# %%
def plot_example(plt, annot, image_file_path, rows, cols, index):
    img = Image.open(image_file_path)
    draw = ImageDraw.Draw(img)
    font = ImageFont.truetype('/usr/share/fonts/dejavu/DejaVuSerif-Bold.ttf', 20)
    
    for a in annot['annotations']:
        box = [
            int(a['left']), int(a['top']),
            int(a['left']) + int(a['width']),
            int(a['top']) + int(a['height'])
        ]
        draw.rectangle(box, outline='yellow', width=4)
        draw.text((box[0], box[1]), classes[int(a['class_id'])], font=font)
    plt.subplot(rows, cols, index + 1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img)
    return plt

def show_random_annotations(plt):
    plt.figure(figsize=(16, 16))
    for i in range(0, 9):
        index = random.randint(0, len(xml_files) - 1)
        
        annot = extract_annotation(xml_files[index])
        image_file_path = os.path.join('data/images/', annot['file'])

        plt = plot_example(plt, annot, image_file_path, 3, 3, i)
    plt.show()

# %%
show_random_annotations(plt)

# %% [markdown]
# __SAGEMAKER SETUP__

# %%
role = sagemaker.get_execution_role()
bucket_name = 'od-imagespets'
training_image = get_image_uri(boto3.Session().region_name, 'object-detection',
                              repo_version='latest')
print(training_image)
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: latest.
# 825641698319.dkr.ecr.us-east-2.amazonaws.com/object-detection:1

# %%
folders = ['train', 'train_annotation', 'validation', 'validation_annotation']

for folder in folders:
    if os.path.isdir(folder):
        shutil.rmtree(folder)
    os.mkdir(folder)

# %% [markdown]
# __PREPARING DATA__

# %%
for xml_file in tqdm(xml_files):
    target_set = 'train' if random.randint(0, 99) < 75 else 'validation'
    annot = extract_annotation(xml_file)
    image_file_path = os.path.join('data/images/', annot['file'])
    image_target_path = os.path.join(target_set, annot['file'])
    shutil.copy(image_file_path, image_target_path)
    json_file_path = os.path.join(target_set + '_annotation', annot['file'][:-3] + 'json')
    with open(json_file_path, 'w') as f:
        json.dump(annot, f)
# Out:
# 100%|██████████| 3686/3686 [00:01<00:00, 2173.50it/s]

# %%
train_images = os.listdir('train')
train_annots = os.listdir('train_annotation')

# %%
print(len(train_annots), len(train_images))
# Out:
# 2745 2745

# %%
for image in train_images:
    key = image.split('.')[0]
    json_file = key + '.json'
    if json_file not in train_annots:
        print('Not found', json_file)

# %% [markdown]
# __UPLOAD DATA TO S3__

# %%
# %%time
sess = sagemaker.Session()

print('Uploading data..')
s3_train_path = sess.upload_data(path='train', bucket=bucket_name, key_prefix='train')
print('Training images uploaded')
s3_train_annotation_path = sess.upload_data(path='train_annotation', bucket=bucket_name,
                                     key_prefix='train_annotation')
print('Training Annotations uploaded')
s3_validation_path = sess.upload_data(path='validation', bucket=bucket_name,
                                      key_prefix='validation')
print('Validation images uploaded')
s3_validation_annotation_path = sess.upload_data(path='validation_annotation', bucket=bucket_name,
                                          key_prefix='validation_annotation')
print('Validation Annotations uploaded')
# Out:
# Uploading data..
# Training images uploaded
# Training Annotations uploaded
# Validation images uploaded
# Validation Annotations uploaded
# CPU times: user 55.2 s, sys: 3.55 s, total: 58.8 s
# Wall time: 5min 43s

# %%
s3_validation_annotation_path
# Out:
# 's3://od-imagespets/validation_annotation'

# %% [markdown]
# __SAGEMAKER MODEL__

# %%
model = sagemaker.estimator.Estimator(
    training_image,
    role=role,
    instance_count=1,
    instance_type='ml.p2.xlarge',
    volume_size=100,
    max_run=36000,
    input_mode='File',
    output_path='s3://od-imagespets/output',
    sagemaker_session=sess
)

# %% [markdown]
# __HYPERPARAMETER TUNNING__

# %%
model.set_hyperparameters(
    base_network='resnet-50',
    num_classes=2,
    use_pretrained_model=1,
    mini_batch_size=16,
    epochs=15,
    learning_rate=0.001,
    lr_scheduler_step='10',
    lr_scheduler_factor=0.1,
    optimizer='sgd',
    momentum=0.9,
    weight_decay=0.0005,
    overlap_threshold=0.5,
    nms_threshold=0.45,
    image_shape=512,
    num_training_samples=len(train_annots)
)

# %% [markdown]
# __DATA CHANNELS__

# %%
train_data = sagemaker.inputs.TrainingInput(s3_train_path, distribution='FullyReplicated',
                          content_type='application/x-image', s3_data_type='S3Prefix')
validation_data = sagemaker.inputs.TrainingInput(s3_validation_path, distribution='FullyReplicated',
                          content_type='application/x-image', s3_data_type='S3Prefix')

train_annotation_data = sagemaker.inputs.TrainingInput(s3_train_annotation_path, distribution='FullyReplicated',
                          content_type='application/x-image', s3_data_type='S3Prefix')
validation_annotation_data = sagemaker.inputs.TrainingInput(s3_validation_annotation_path, distribution='FullyReplicated',
                          content_type='application/x-image', s3_data_type='S3Prefix')

# %%
data_channels = {
    'train': train_data,
    'train_annotation': train_annotation_data,
    'validation': validation_data,
    'validation_annotation': validation_annotation_data
}

# %% [markdown]
# __MODEL TRAINING__

# %%
model.fit(inputs=data_channels, logs=True)
# Out:
# 2021-01-18 20:15:22 Starting - Starting the training job...
# 2021-01-18 20:15:46 Starting - Launching requested ML instancesProfilerReport-1611000922: InProgress
# ......
# 2021-01-18 20:16:47 Starting - Preparing the instances for training.........
# 2021-01-18 20:18:08 Downloading - Downloading input data......
# 2021-01-18 20:19:09 Training - Downloading the training image...
# 2021-01-18 20:19:49 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# [01/18/2021 20:19:42 INFO 140251450963776] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'label_width': u'350', u'early_stopping_min_epochs': u'10', u'epochs': u'30', u'overlap_threshold': u'0.5', u'lr_scheduler_factor': u'0.1', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0005', u'mini_batch_size': u'32', u'use_pretrained_model': u'0', u'freeze_layer_pattern': u'', u'lr_scheduler_step': u'', u'early_stopping': u'False', u'early_stopping_patience': u'5', u'momentum': u'0.9', u'num_training_samples': u'', u'optimizer': u'sgd', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.0', u'learning_rate': u'0.001', u'kv_store': u'device', u'nms_threshold': u'0.45', u'num_classes': u'', u'base_network': u'vgg-16', u'nms_topk': u'400', u'_kvstore': u'device', u'image_shape': u'300'}
# [01/18/2021 20:19:42 INFO 140251450963776] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'learning_rate': u'0.001', u'epochs': u'15', u'nms_threshold': u'0.45', u'optimizer': u'sgd', u'base_network': u'resnet-50', u'image_shape': u'512', u'lr_scheduler_step': u'10', u'momentum': u'0.9', u'overlap_threshold': u'0.5', u'num_training_samples': u'2745', u'mini_batch_size': u'16', u'weight_decay': u'0.0005', u'use_pretrained_model': u'1', u'num_classes': u'2', u'lr_scheduler_factor': u'0.1'}
# [01/18/2021 20:19:42 INFO 140251450963776] Final configuration: {u'label_width': u'350', u'early_stopping_min_epochs': u'10', u'epochs': u'15', u'overlap_threshold': u'0.5', u'lr_scheduler_factor': u'0.1', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0005', u'mini_batch_size': u'16', u'use_pretrained_model': u'1', u'freeze_layer_pattern': u'', u'lr_scheduler_step': u'10', u'early_stopping': u'False', u'early_stopping_patience': u'5', u'momentum': u'0.9', u'num_training_samples': u'2745', u'optimizer': u'sgd', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.0', u'learning_rate': u'0.001', u'kv_store': u'device', u'nms_threshold': u'0.45', u'num_classes': u'2', u'base_network': u'resnet-50', u'nms_topk': u'400', u'_kvstore': u'device', u'image_shape': u'512'}
# Process 1 is a worker.
# [01/18/2021 20:19:42 INFO 140251450963776] Using default worker.
# [01/18/2021 20:19:42 INFO 140251450963776] Loaded iterator creator application/x-image for content type ('application/x-image', '1.0')
# [01/18/2021 20:19:42 INFO 140251450963776] Loaded iterator creator application/x-recordio for content type ('application/x-recordio', '1.0')
# [01/18/2021 20:19:42 INFO 140251450963776] Loaded iterator creator image/png for content type ('image/png', '1.0')
# [01/18/2021 20:19:42 INFO 140251450963776] Loaded iterator creator image/jpeg for content type ('image/jpeg', '1.0')
# [01/18/2021 20:19:42 INFO 140251450963776] Checkpoint loading and saving are disabled.
# [01/18/2021 20:19:42 INFO 140251450963776] nvidia-smi took: 0.100384950638 secs to identify 1 gpus
# Creating .rec file from /opt/ml/input/data/train/train.lst in /opt/ml/input/data/train
# time: 0.0551650524139  count: 0
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# time: 2.42799305916  count: 1000
# time: 2.1001470089  count: 2000
# Creating .rec file from /opt/ml/input/data/validation/val.lst in /opt/ml/input/data/validation
# time: 0.0121037960052  count: 0
# Corrupt JPEG data: premature end of data segment
# [01/18/2021 20:19:53 INFO 140251450963776] Number of GPUs being used: 1
# [01/18/2021 20:19:53 WARNING 140251450963776] Training images are resized to image shape (3, 512, 512)
# [20:19:53] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/train/train.rec, use 3 threads for decoding..
# [20:19:53] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/train/train.rec, label padding width: 350
# [01/18/2021 20:19:56 WARNING 140251450963776] Validation images are resized to image shape (3, 512, 512)
# [20:19:56] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/validation/val.rec, use 3 threads for decoding..
# [20:19:56] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/validation/val.rec, label padding width: 350
# [01/18/2021 20:19:59 INFO 140251450963776] Number of GPUs being used: 1
# [01/18/2021 20:19:59 INFO 140251450963776] Using [gpu(0)] as training context.
# [01/18/2021 20:19:59 INFO 140251450963776] Number of GPUs being used: 1
# [01/18/2021 20:19:59 INFO 140251450963776] Create Store: device
# [01/18/2021 20:19:59 INFO 140251450963776] Using (gpu(0)) as training context.
# [01/18/2021 20:19:59 INFO 140251450963776] Start training from pretrained model 1.
# [20:19:59] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v0.8.0. Attempting to upgrade...
# [20:19:59] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# [01/18/2021 20:20:00 INFO 140251450963776] Loaded pretrained model parameters.
# [01/18/2021 20:20:11 INFO 140251450963776] Creating a new state instance.
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1611001211.170499, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection"}, "StartTime": 1611001211.170398}
#
# [20:20:11] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [01/18/2021 20:23:26 INFO 140251450963776] Epoch:    0, batches:    100, num_examples:   1600, 8.2 samples/sec, epoch time so far:  0:03:15.533056
# [01/18/2021 20:25:31 INFO 140251450963776] #quality_metric: host=algo-1, epoch=0, batch=172 train cross_entropy <loss>=(1.100300321111984)
# [01/18/2021 20:25:31 INFO 140251450963776] #quality_metric: host=algo-1, epoch=0, batch=172 train smooth_l1 <loss>=(0.6384831165698124)
# [01/18/2021 20:25:31 INFO 140251450963776] Round of batches complete
# [01/18/2021 20:25:32 INFO 140251450963776] Updated the metrics
# [01/18/2021 20:26:14 INFO 140251450963776] #quality_metric: host=algo-1, epoch=0, validation mAP <score>=(0.14241012268647157)
# [01/18/2021 20:26:14 INFO 140251450963776] Updating the best model with validation-mAP=0.14241012268647157
# [01/18/2021 20:26:14 INFO 140251450963776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/18/2021 20:26:14 INFO 140251450963776] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1611001574.157795, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 0}, "StartTime": 1611001211.170835}
#
# [01/18/2021 20:29:07 INFO 140251450963776] Epoch:    1, batches:    100, num_examples:   1600, 9.2 samples/sec, epoch time so far:  0:02:53.653222
# [01/18/2021 20:31:12 INFO 140251450963776] #quality_metric: host=algo-1, epoch=1, batch=172 train cross_entropy <loss>=(0.8570543211725291)
# [01/18/2021 20:31:12 INFO 140251450963776] #quality_metric: host=algo-1, epoch=1, batch=172 train smooth_l1 <loss>=(0.5765476139209743)
# [01/18/2021 20:31:12 INFO 140251450963776] Round of batches complete
# [01/18/2021 20:31:12 INFO 140251450963776] Updated the metrics
# [01/18/2021 20:31:54 INFO 140251450963776] #quality_metric: host=algo-1, epoch=1, validation mAP <score>=(0.3264108593909432)
# [01/18/2021 20:31:54 INFO 140251450963776] Updating the best model with validation-mAP=0.3264108593909432
# [01/18/2021 20:31:54 INFO 140251450963776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/18/2021 20:31:54 INFO 140251450963776] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1611001914.544699, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 1}, "StartTime": 1611001574.157972}
#
# [01/18/2021 20:34:48 INFO 140251450963776] Epoch:    2, batches:    100, num_examples:   1600, 9.2 samples/sec, epoch time so far:  0:02:53.721569
# [01/18/2021 20:36:52 INFO 140251450963776] #quality_metric: host=algo-1, epoch=2, batch=171 train cross_entropy <loss>=(0.730774815211402)
# [01/18/2021 20:36:52 INFO 140251450963776] #quality_metric: host=algo-1, epoch=2, batch=171 train smooth_l1 <loss>=(0.5280883715751423)
# [01/18/2021 20:36:52 INFO 140251450963776] Round of batches complete
# [01/18/2021 20:36:52 INFO 140251450963776] Updated the metrics
# [01/18/2021 20:37:33 INFO 140251450963776] #quality_metric: host=algo-1, epoch=2, validation mAP <score>=(0.6096329072223665)
# [01/18/2021 20:37:33 INFO 140251450963776] Updating the best model with validation-mAP=0.6096329072223665
# [01/18/2021 20:37:33 INFO 140251450963776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/18/2021 20:37:33 INFO 140251450963776] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1611002253.879744, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 2}, "StartTime": 1611001914.544922}
#
# [01/18/2021 20:40:28 INFO 140251450963776] Epoch:    3, batches:    100, num_examples:   1600, 9.2 samples/sec, epoch time so far:  0:02:54.818488
# [01/18/2021 20:42:34 INFO 140251450963776] #quality_metric: host=algo-1, epoch=3, batch=172 train cross_entropy <loss>=(0.6497523349512367)
# [01/18/2021 20:42:34 INFO 140251450963776] #quality_metric: host=algo-1, epoch=3, batch=172 train smooth_l1 <loss>=(0.45871599361819304)
# [01/18/2021 20:42:34 INFO 140251450963776] Round of batches complete
# [01/18/2021 20:42:34 INFO 140251450963776] Updated the metrics
# [01/18/2021 20:43:16 INFO 140251450963776] #quality_metric: host=algo-1, epoch=3, validation mAP <score>=(0.7928710524264782)
# [01/18/2021 20:43:16 INFO 140251450963776] Updating the best model with validation-mAP=0.7928710524264782
# [01/18/2021 20:43:16 INFO 140251450963776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/18/2021 20:43:16 INFO 140251450963776] #progress_metric: host=algo-1, completed 26 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1611002596.700211, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 3}, "StartTime": 1611002253.880012}
#
# [01/18/2021 20:46:10 INFO 140251450963776] Epoch:    4, batches:    100, num_examples:   1600, 9.2 samples/sec, epoch time so far:  0:02:54.179182
# [01/18/2021 20:48:14 INFO 140251450963776] #quality_metric: host=algo-1, epoch=4, batch=171 train cross_entropy <loss>=(0.5958842865026361)
# [01/18/2021 20:48:14 INFO 140251450963776] #quality_metric: host=algo-1, epoch=4, batch=171 train smooth_l1 <loss>=(0.38155672940305213)
# [01/18/2021 20:48:14 INFO 140251450963776] Round of batches complete
# [01/18/2021 20:48:14 INFO 140251450963776] Updated the metrics
# [01/18/2021 20:48:56 INFO 140251450963776] #quality_metric: host=algo-1, epoch=4, validation mAP <score>=(0.8956372457704124)
# [01/18/2021 20:48:56 INFO 140251450963776] Updating the best model with validation-mAP=0.8956372457704124
# [01/18/2021 20:48:56 INFO 140251450963776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/18/2021 20:48:56 INFO 140251450963776] #progress_metric: host=algo-1, completed 33 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1611002936.492941, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 4}, "StartTime": 1611002596.700408}
#
# [01/18/2021 20:51:50 INFO 140251450963776] Epoch:    5, batches:    100, num_examples:   1600, 9.2 samples/sec, epoch time so far:  0:02:53.804292
# [01/18/2021 20:53:55 INFO 140251450963776] #quality_metric: host=algo-1, epoch=5, batch=172 train cross_entropy <loss>=(0.5667631188375027)
# [01/18/2021 20:53:55 INFO 140251450963776] #quality_metric: host=algo-1, epoch=5, batch=172 train smooth_l1 <loss>=(0.3288442409524066)
# [01/18/2021 20:53:55 INFO 140251450963776] Round of batches complete
# [01/18/2021 20:53:55 INFO 140251450963776] Updated the metrics
# [01/18/2021 20:54:36 INFO 140251450963776] #quality_metric: host=algo-1, epoch=5, validation mAP <score>=(0.9440391325699533)
# [01/18/2021 20:54:36 INFO 140251450963776] Updating the best model with validation-mAP=0.9440391325699533
# [01/18/2021 20:54:37 INFO 140251450963776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/18/2021 20:54:37 INFO 140251450963776] #progress_metric: host=algo-1, completed 40 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 6, "sum": 6.0, "min": 6}}, "EndTime": 1611003277.062257, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 5}, "StartTime": 1611002936.493136}
#
# [01/18/2021 20:57:30 INFO 140251450963776] Epoch:    6, batches:    100, num_examples:   1600, 9.2 samples/sec, epoch time so far:  0:02:53.595418
# [01/18/2021 20:59:33 INFO 140251450963776] #quality_metric: host=algo-1, epoch=6, batch=171 train cross_entropy <loss>=(0.5367743749396294)
# [01/18/2021 20:59:33 INFO 140251450963776] #quality_metric: host=algo-1, epoch=6, batch=171 train smooth_l1 <loss>=(0.29432169816325854)
# [01/18/2021 20:59:33 INFO 140251450963776] Round of batches complete
# [01/18/2021 20:59:33 INFO 140251450963776] Updated the metrics
# [01/18/2021 21:00:15 INFO 140251450963776] #quality_metric: host=algo-1, epoch=6, validation mAP <score>=(0.9763621608553577)
# [01/18/2021 21:00:15 INFO 140251450963776] Updating the best model with validation-mAP=0.9763621608553577
# [01/18/2021 21:00:15 INFO 140251450963776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/18/2021 21:00:15 INFO 140251450963776] #progress_metric: host=algo-1, completed 46 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 7, "sum": 7.0, "min": 7}}, "EndTime": 1611003615.688117, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 6}, "StartTime": 1611003277.062462}
#
# [01/18/2021 21:03:09 INFO 140251450963776] Epoch:    7, batches:    100, num_examples:   1600, 9.2 samples/sec, epoch time so far:  0:02:53.567076
# [01/18/2021 21:05:13 INFO 140251450963776] #quality_metric: host=algo-1, epoch=7, batch=172 train cross_entropy <loss>=(0.5095082628236267)
# [01/18/2021 21:05:13 INFO 140251450963776] #quality_metric: host=algo-1, epoch=7, batch=172 train smooth_l1 <loss>=(0.2695899326249031)
# [01/18/2021 21:05:13 INFO 140251450963776] Round of batches complete
# [01/18/2021 21:05:13 INFO 140251450963776] Updated the metrics
# [01/18/2021 21:05:55 INFO 140251450963776] #quality_metric: host=algo-1, epoch=7, validation mAP <score>=(0.9796886389963144)
# [01/18/2021 21:05:55 INFO 140251450963776] Updating the best model with validation-mAP=0.9796886389963144
# [01/18/2021 21:05:55 INFO 140251450963776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/18/2021 21:05:55 INFO 140251450963776] #progress_metric: host=algo-1, completed 53 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 8, "sum": 8.0, "min": 8}}, "EndTime": 1611003955.340273, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 7}, "StartTime": 1611003615.688316}
#
# [01/18/2021 21:08:48 INFO 140251450963776] Epoch:    8, batches:    100, num_examples:   1600, 9.3 samples/sec, epoch time so far:  0:02:52.778505
# [01/18/2021 21:10:51 INFO 140251450963776] #quality_metric: host=algo-1, epoch=8, batch=172 train cross_entropy <loss>=(0.4916289936059461)
# [01/18/2021 21:10:51 INFO 140251450963776] #quality_metric: host=algo-1, epoch=8, batch=172 train smooth_l1 <loss>=(0.2465127306574719)
# [01/18/2021 21:10:51 INFO 140251450963776] Round of batches complete
# [01/18/2021 21:10:52 INFO 140251450963776] Updated the metrics
# [01/18/2021 21:11:33 INFO 140251450963776] #quality_metric: host=algo-1, epoch=8, validation mAP <score>=(0.9853206568501773)
# [01/18/2021 21:11:33 INFO 140251450963776] Updating the best model with validation-mAP=0.9853206568501773
# [01/18/2021 21:11:33 INFO 140251450963776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/18/2021 21:11:33 INFO 140251450963776] #progress_metric: host=algo-1, completed 60 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 9, "sum": 9.0, "min": 9}}, "EndTime": 1611004293.471967, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 8}, "StartTime": 1611003955.340473}
#
# [01/18/2021 21:14:26 INFO 140251450963776] Epoch:    9, batches:    100, num_examples:   1600, 9.3 samples/sec, epoch time so far:  0:02:52.549860
# [01/18/2021 21:16:28 INFO 140251450963776] #quality_metric: host=algo-1, epoch=9, batch=171 train cross_entropy <loss>=(0.47699715188011327)
# [01/18/2021 21:16:28 INFO 140251450963776] #quality_metric: host=algo-1, epoch=9, batch=171 train smooth_l1 <loss>=(0.22606844520646288)
# [01/18/2021 21:16:28 INFO 140251450963776] Round of batches complete
# [01/18/2021 21:16:28 INFO 140251450963776] Updated the metrics
# [01/18/2021 21:17:10 INFO 140251450963776] #quality_metric: host=algo-1, epoch=9, validation mAP <score>=(0.983249552152131)
# [01/18/2021 21:17:10 INFO 140251450963776] #progress_metric: host=algo-1, completed 66 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1611004630.020727, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 9}, "StartTime": 1611004293.472165}
#
# [01/18/2021 21:20:02 INFO 140251450963776] Epoch:    10, batches:    100, num_examples:   1600, 9.3 samples/sec, epoch time so far:  0:02:52.033342
# [01/18/2021 21:22:05 INFO 140251450963776] #quality_metric: host=algo-1, epoch=10, batch=172 train cross_entropy <loss>=(0.4645779545102179)
# [01/18/2021 21:22:05 INFO 140251450963776] #quality_metric: host=algo-1, epoch=10, batch=172 train smooth_l1 <loss>=(0.2182353215383268)
# [01/18/2021 21:22:05 INFO 140251450963776] Round of batches complete
# [01/18/2021 21:22:05 INFO 140251450963776] Updated the metrics
# [01/18/2021 21:22:46 INFO 140251450963776] #quality_metric: host=algo-1, epoch=10, validation mAP <score>=(0.979118475458741)
# [01/18/2021 21:22:46 INFO 140251450963776] #progress_metric: host=algo-1, completed 73 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 11, "sum": 11.0, "min": 11}}, "EndTime": 1611004966.369357, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 10}, "StartTime": 1611004630.020909}
#
# [01/18/2021 21:25:37 INFO 140251450963776] Epoch:    11, batches:    100, num_examples:   1600, 9.4 samples/sec, epoch time so far:  0:02:50.798160
# [01/18/2021 21:27:38 INFO 140251450963776] #quality_metric: host=algo-1, epoch=11, batch=171 train cross_entropy <loss>=(0.4453526087270142)
# [01/18/2021 21:27:38 INFO 140251450963776] #quality_metric: host=algo-1, epoch=11, batch=171 train smooth_l1 <loss>=(0.199947676184179)
# [01/18/2021 21:27:38 INFO 140251450963776] Round of batches complete
# [01/18/2021 21:27:38 INFO 140251450963776] Updated the metrics
# [01/18/2021 21:28:19 INFO 140251450963776] #quality_metric: host=algo-1, epoch=11, validation mAP <score>=(0.9864152882798636)
# [01/18/2021 21:28:19 INFO 140251450963776] Updating the best model with validation-mAP=0.9864152882798636
# [01/18/2021 21:28:19 INFO 140251450963776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/18/2021 21:28:19 INFO 140251450963776] #progress_metric: host=algo-1, completed 80 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 12, "sum": 12.0, "min": 12}}, "EndTime": 1611005299.726389, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 11}, "StartTime": 1611004966.369581}
#
# [01/18/2021 21:31:10 INFO 140251450963776] Epoch:    12, batches:    100, num_examples:   1600, 9.4 samples/sec, epoch time so far:  0:02:50.838996
# [01/18/2021 21:33:14 INFO 140251450963776] #quality_metric: host=algo-1, epoch=12, batch=172 train cross_entropy <loss>=(0.433343441942803)
# [01/18/2021 21:33:14 INFO 140251450963776] #quality_metric: host=algo-1, epoch=12, batch=172 train smooth_l1 <loss>=(0.19106023735986177)
# [01/18/2021 21:33:14 INFO 140251450963776] Round of batches complete
# [01/18/2021 21:33:14 INFO 140251450963776] Updated the metrics
# [01/18/2021 21:33:54 INFO 140251450963776] #quality_metric: host=algo-1, epoch=12, validation mAP <score>=(0.9891797275532839)
# [01/18/2021 21:33:54 INFO 140251450963776] Updating the best model with validation-mAP=0.9891797275532839
# [01/18/2021 21:33:54 INFO 140251450963776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/18/2021 21:33:54 INFO 140251450963776] #progress_metric: host=algo-1, completed 86 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 13, "sum": 13.0, "min": 13}}, "EndTime": 1611005634.975659, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 12}, "StartTime": 1611005299.72738}
#
# [01/18/2021 21:36:45 INFO 140251450963776] Epoch:    13, batches:    100, num_examples:   1600, 9.4 samples/sec, epoch time so far:  0:02:50.633882
# [01/18/2021 21:38:47 INFO 140251450963776] #quality_metric: host=algo-1, epoch=13, batch=171 train cross_entropy <loss>=(0.4251826913990803)
# [01/18/2021 21:38:47 INFO 140251450963776] #quality_metric: host=algo-1, epoch=13, batch=171 train smooth_l1 <loss>=(0.17800307581548513)
# [01/18/2021 21:38:47 INFO 140251450963776] Round of batches complete
# [01/18/2021 21:38:47 INFO 140251450963776] Updated the metrics
# [01/18/2021 21:39:27 INFO 140251450963776] #quality_metric: host=algo-1, epoch=13, validation mAP <score>=(0.9909957130800011)
# [01/18/2021 21:39:27 INFO 140251450963776] Updating the best model with validation-mAP=0.9909957130800011
# [01/18/2021 21:39:27 INFO 140251450963776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/18/2021 21:39:27 INFO 140251450963776] #progress_metric: host=algo-1, completed 93 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 14, "sum": 14.0, "min": 14}}, "EndTime": 1611005967.508517, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 13}, "StartTime": 1611005634.975868}
#
# [01/18/2021 21:42:18 INFO 140251450963776] Epoch:    14, batches:    100, num_examples:   1600, 9.4 samples/sec, epoch time so far:  0:02:50.867022
# [01/18/2021 21:44:21 INFO 140251450963776] #quality_metric: host=algo-1, epoch=14, batch=172 train cross_entropy <loss>=(0.4128505547552922)
# [01/18/2021 21:44:21 INFO 140251450963776] #quality_metric: host=algo-1, epoch=14, batch=172 train smooth_l1 <loss>=(0.17485513045773868)
# [01/18/2021 21:44:21 INFO 140251450963776] Round of batches complete
# [01/18/2021 21:44:21 INFO 140251450963776] Updated the metrics
# [01/18/2021 21:45:01 INFO 140251450963776] #quality_metric: host=algo-1, epoch=14, validation mAP <score>=(0.9860136105371804)
# [01/18/2021 21:45:01 INFO 140251450963776] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1611006301.480608, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 14}, "StartTime": 1611005967.508807}
#
# [01/18/2021 21:45:01 WARNING 140251450963776] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [01/18/2021 21:45:01 INFO 140251450963776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [01/18/2021 21:45:01 INFO 140251450963776] Test data is not provided.
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}, "totaltime": {"count": 1, "max": 5120031.9311618805, "sum": 5120031.9311618805, "min": 5120031.9311618805}, "setuptime": {"count": 1, "max": 11.293172836303711, "sum": 11.293172836303711, "min": 11.293172836303711}}, "EndTime": 1611006302.068446, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/Object Detection"}, "StartTime": 1611001182.151629}
#
#
# 2021-01-18 21:45:40 Uploading - Uploading generated training model
# 2021-01-18 21:46:14 Completed - Training job completed
# ProfilerReport-1611000922: IssuesFound
# Training seconds: 5280
# Billable seconds: 5280

# %%
deployed_model = model.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
print('\nModel deployed!')
# Out:
# -----------------!
# Model deployed!

# %%
image_dir = 'validation'
images = [x for x in os.listdir(image_dir) if x[-3:] == 'jpg']
print(len(images))
# Out:
# 941

# %%
index = 0

image_path = os.path.join(image_dir, images[index])
#image_path = 'dog_cat.jfif'

with open(image_path, 'rb') as f:
    b = bytearray(f.read())

results = deployed_model.predict(b, initial_args={"ContentType": "image/jpeg"})
results = json.loads(results)

preds = results['prediction']

# %%
preds
# Out:
# [[0.0,
#   0.9464716911315918,
#   0.4935493469238281,
#   0.04106844961643219,
#   0.7338902950286865,
#   0.33046072721481323],
#  [1.0,
#   0.14028333127498627,
#   0.12255537509918213,
#   0.04294440150260925,
#   0.8788479566574097,
#   0.8914197683334351],
#  [0.0,
#   0.08424536883831024,
#   0.5323541760444641,
#   0.054056569933891296,
#   0.6901931166648865,
#   0.23117785155773163],
#  [1.0,
#   0.04390214383602142,
#   0.12247797846794128,
#   0.34790313243865967,
#   0.7234817743301392,
#   0.8137155771255493],
#  [1.0,
#   0.03837239369750023,
#   0.5312314629554749,
#   0.11124590784311295,
#   0.6858890652656555,
#   0.29065388441085815],
#  [0.0,
#   0.027627984061837196,
#   0.4300681948661804,
#   0.12008411437273026,
#   0.694950520992279,
#   0.2930949926376343],
#  [1.0,
#   0.027394386008381844,
#   0.39171895384788513,
#   0.025564908981323242,
#   0.773962140083313,
#   0.6843075156211853],
#  [1.0,
#   0.027268309146165848,
#   0.38744962215423584,
#   0.34727269411087036,
#   0.9256389141082764,
#   0.9664553999900818],
#  [0.0,
#   0.027143342420458794,
#   0.4216926097869873,
#   0.0,
#   0.7721097469329834,
#   0.48944997787475586],
#  [1.0,
#   0.020864548161625862,
#   0.558186411857605,
#   0.16931013762950897,
#   0.7131568193435669,
#   0.1462547779083252],
#  [1.0,
#   0.010331312194466591,
#   0.5108395218849182,
#   0.0782942846417427,
#   0.5881265997886658,
#   0.20796841382980347],
#  [1.0,
#   0.010315968655049801,
#   0.7648119330406189,
#   0.03901882842183113,
#   0.8969480395317078,
#   0.11678159236907959],
#  [1.0,
#   0.010298274457454681,
#   0.8834614753723145,
#   0.27809688448905945,
#   0.9534966945648193,
#   0.3940911591053009],
#  [1.0,
#   0.010278737172484398,
#   0.7232908010482788,
#   0.5542463064193726,
#   0.8658171892166138,
#   0.72484290599823],
#  [0.0,
#   0.010255645029246807,
#   0.5902183055877686,
#   0.10884448885917664,
#   0.7239750623703003,
#   0.29040342569351196],
#  [1.0,
#   0.010254480876028538,
#   0.29333341121673584,
#   0.4141825735569,
#   0.43019014596939087,
#   0.49080386757850647],
#  [1.0,
#   0.010237406939268112,
#   0.8842897415161133,
#   0.8065158724784851,
#   0.955466628074646,
#   0.9253621697425842],
#  [1.0,
#   0.010232633911073208,
#   0.6658766269683838,
#   0.5478397607803345,
#   0.7409286499023438,
#   0.6788145303726196],
#  [0.0,
#   0.010228192433714867,
#   0.06434103101491928,
#   0.007906079292297363,
#   0.21772733330726624,
#   0.15337024629116058],
#  [0.0,
#   0.010198904201388359,
#   0.6261296272277832,
#   0.9082319736480713,
#   0.7821977138519287,
#   1.0],
#  [0.0,
#   0.010180165059864521,
#   0.8233835101127625,
#   0.2905411720275879,
#   0.954779326915741,
#   0.36781978607177734],
#  [1.0,
#   0.010176025331020355,
#   0.850939154624939,
#   0.2381601333618164,
#   0.9266669750213623,
#   0.36324751377105713],
#  [1.0,
#   0.010146941058337688,
#   0.9564599990844727,
#   0.2073063999414444,
#   1.0,
#   0.33026018738746643],
#  [1.0,
#   0.010128972120583057,
#   0.3503614068031311,
#   0.41551271080970764,
#   0.49053412675857544,
#   0.49345603585243225],
#  [1.0,
#   0.010114346630871296,
#   0.7899180054664612,
#   0.8507994413375854,
#   0.9246236681938171,
#   0.9288220405578613],
#  [1.0,
#   0.010094680823385715,
#   0.2486838400363922,
#   0.27750834822654724,
#   0.4214646518230438,
#   0.4400443136692047],
#  [1.0,
#   0.01006048172712326,
#   0.0,
#   0.3920021057128906,
#   0.35752353072166443,
#   0.743138313293457],
#  [1.0,
#   0.010054933838546276,
#   0.8335636258125305,
#   0.5928094387054443,
#   1.0,
#   0.7134203910827637],
#  [1.0,
#   0.010013536550104618,
#   0.8217325806617737,
#   0.397706001996994,
#   0.8966501355171204,
#   0.5243962407112122],
#  [1.0,
#   0.010005297139286995,
#   0.3242056369781494,
#   0.1329174041748047,
#   0.4623878598213196,
#   0.21349555253982544]]

# %%
img = Image.open(image_path)
draw = ImageDraw.Draw(img)
font = ImageFont.truetype('/usr/share/fonts/dejavu/DejaVuSerif-Bold.ttf', 30)
w, h =img.size

for pred in preds:
    class_id, score, xmin, ymin, xmax, ymax = pred
    
    if score > 0.7:
        box = [w*xmin, h*ymin, w*xmax, h*ymax]

        draw.rectangle(box, outline='yellow', width=4)
        draw.text((box[0], box[1]), classes[int(class_id)], font=font, fill='#000000')
    else:
        break

plt.xticks([])
plt.yticks([])
plt.imshow(img)
plt.show()
